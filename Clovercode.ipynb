# %%
# Version 1
# Dataset: 4-leaf clover dataset
# Total Images: 376

# !pip install ultralytics roboflow

from ultralytics import YOLO
from roboflow import Roboflow

rf = Roboflow(api_key="YOUR_API_KEY")

project = rf.workspace("YOUR_WORKSPACE").project("YOUR_PROJECT")
version = project.version(1)

dataset = version.download("yolov8")

model = YOLO("yolov8n.pt")

model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    device="cuda",
    name="clover_detector"
)

from google.colab import files
files.download("runs/detect/<training_folder>/weights/best.pt")

# %%
#Version 2
#Used dataset having both 3&4 clover(total 3355 imgs)

# !pip install ultralytics roboflow

from ultralytics import YOLO
from roboflow import Roboflow

rf = Roboflow(api_key="YOUR_API_KEY")

project = rf.workspace("YOUR_WORKSPACE").project("YOUR_PROJECT")
version = project.version(1)

dataset = version.download("yolov8")

model = YOLO("yolov8n.pt")

model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    device="cuda",
    name="clover_detector"
)

from google.colab import files
files.download("runs/detect/<training_folder>/weights/best.pt")

# %%
#Version 3
#Used dataset having both 3&4 clover(total 1403 imgs)
# !pip install ultralytics roboflow

from ultralytics import YOLO
from roboflow import Roboflow

rf = Roboflow(api_key="YOUR_API_KEY")

project = rf.workspace("YOUR_WORKSPACE").project("YOUR_PROJECT")
version = project.version(1)

dataset = version.download("yolov8")

model = YOLO("yolov8n.pt")

model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    device="cuda",
    name="clover_detector"
)

from google.colab import files
files.download("runs/detect/<training_folder>/weights/best.pt")

# %%
#Version 4
#Used dataset having both 3&4 clover(total 1194 imgs)

# !pip install ultralytics roboflow

from ultralytics import YOLO
from roboflow import Roboflow

rf = Roboflow(api_key="YOUR_API_KEY")

project = rf.workspace("YOUR_WORKSPACE").project("YOUR_PROJECT")
version = project.version(1)

dataset = version.download("yolov8")

model = YOLO("yolov8n.pt")

model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=100,
    imgsz=700,
    batch=16,
    device="cuda",
    name="clover_detector"
)

from google.colab import files
files.download("runs/detect/<training_folder>/weights/best.pt")
